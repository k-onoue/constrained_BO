# %%
import os
import pandas as pd

project_dir_path = "/Users/keisukeonoue/ws/constrained_BO/"
df = pd.read_csv(os.path.join(project_dir_path, "data/論文調査_制約付きベイズ最適化 - シート1 のコピー.csv"))
df
# Out:
#                                                   論文名  重要度     年  \
# 0       Bayesian Optimization with Discrete Variables  NaN  2019
# 1   Bayesian Optimization over Discrete and Mixed ...  NaN  2022
# 2   Bayesian Optimization with Inequality Constraints  NaN  2014
# 3      Bayesian Optimization with Unknown Constraints  NaN  2014
# 4   c-TPE: Generalizing Tree-structured Parzen Est...  NaN  2022
# 5   Amortized Bayesian Optimization over Discrete ...  NaN  2020
# 6   Constrained Bayesian Optimization for Automati...  NaN  2017
# 7   Constrained Bayesian optimization for automati...  NaN  2019
# 8   Stagewise safe bayesian optimization with gaus...  NaN  2018
# 9   A Bayesian approach to constrained single-and ...  NaN  2015
# 10  Lookahead Bayesian Optimization with Inequalit...  NaN  2017
# 11  Two-step Lookahead Bayesian Optimization with ...  NaN  2021
# 12  Resource-Constraint Bayesian Optimization for ...  NaN  2024
# ...

# %%
print(df.head())
# Out:
#                                                  論文名  重要度     年  \
# 0      Bayesian Optimization with Discrete Variables  NaN  2019
# 1  Bayesian Optimization over Discrete and Mixed ...  NaN  2022
# 2  Bayesian Optimization with Inequality Constraints  NaN  2014
# 3     Bayesian Optimization with Unknown Constraints  NaN  2014
# 4  c-TPE: Generalizing Tree-structured Parzen Est...  NaN  2022
#
#                                                  url  \
# 0  https://dro.deakin.edu.au/articles/conference_...
# 1  https://proceedings.neurips.cc/paper_files/pap...
# 2    https://proceedings.mlr.press/v32/gardner14.pdf
# 3                    https://arxiv.org/abs/1403.5607
# 4                   https://arxiv.org/abs/2211.14411
#
#                                              実装の有無  \
# 0                                              NaN
# 1        https://github.com/facebookresearch/bo_pr
# 2                                              NaN
# ...
